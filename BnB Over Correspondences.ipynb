# %%
using JuMP
using Gurobi
using StaticArrays
using Rotations
using DataStructures
using GeometryTypes
using DrakeVisualizer
using FileIO
using CoordinateTransformations
using Plots
using PyPlot
using Clp
using ForwardDiff

include("MeshSampling.jl")
using MeshSampling

include("PoseEstimationMathematicalProgram.jl")
using PoseEstimationMathematicalProgram

vis = Visualizer();

# %%
# Core parameters we care about

# This many points are sampled on the surface of the model, and
# are used as inliers in the scene cloud.
N_model_points = 8
# This many additional outliers are sampled randomly from a volume around
# the model ([-5, 5]^3) to build the scene cloud.
N_outliers = 2;

# %% [markdown]
# Build up information concerning an object of interest:

# %%
box = load("cube.obj")

points = decompose(Point{3,Float64}, box)
faces = decompose(Face{3, Int, 0}, box)

# Sample N points from the surface of the mesh
ret = MeshSampling.samplePointsFromMesh(N_model_points, points, faces);
modelPoints = ret[1]
modelPointsFacesGT = ret[2];

# %% [markdown]
# Using that model, build up a scene cloud:

# %%
T0 = [0.1; 0; 0.5]
R0 = [0.860089 0.174349 -0.479426; 0.244566 0.683829 0.687434; 0.447698 -0.708506 0.545514]

function convertToPointCloudType(points)
    return PointCloud([[points[1, i], points[2, i], points[3, i]] for i=1:size(points, 2)]) 
end

scenePoints = transpose(R0)*modelPoints + repmat(-transpose(R0)*T0, 1, size(modelPoints, 2))

scenePointsOutliers = (rand(3, N_outliers)-0.5)*10.
scenePoints = cat(2, scenePoints, scenePointsOutliers)
scenePointsFacesGT = cat(1, modelPointsFacesGT, zeros(N_outliers, size(modelPointsFacesGT, 2)))
outliersGTAssignment = zeros(N_model_points+N_outliers, 1)
outliersGTAssignment[N_model_points+1:end] = 1


pointcloud = convertToPointCloudType(scenePoints)
box_vis = setgeometry!(vis[:julia][:box_vis], box)
setgeometry!(vis[:julia][:scene_pts], pointcloud);
# Out:
# WARNING: Method definition convertToPointCloudType(Any) in module Main at In[66]:5 overwritten at In[67]:5.

# %% [markdown]
# We want to solve the problem
#
# $$ \min_{R, T, C} \sum_{i \in S} || R s_i + T - C M ||_1 $$
#
# where $C$ selects model vertices $M$ to explain scene point $S_i$, using
# only model vertices from a single face of the model at a time, and $R \in SO(3)$.

# %%
function buildModelHelper()
    return PoseEstimationMathematicalProgram.constructModel(
        scenePoints, points, faces, use_relaxed_form=true,
    other_solver=GurobiSolver(TimeLimit = 1, FeasRelaxBigM = 20, MIPGap = 0.025, Heuristics = 0.1, Threads = 10, OutputFlag=0),
        closeness=10.0, R0_in=R0, optPhiMax=0.1, optBigNumber=10,
    TimeLimit = 1200, FeasRelaxBigM = 20, MIPGap = 0.025, Heuristics = 0.1, Threads = 5, OutputFlag=0);
end
fullyRelaxedModel = buildModelHelper();

# %%
function buildRandomPartialFaceAssignment(scenePoints, faces, points, N)
    nx = size(scenePoints, 2)
    ny = size(faces, 1)
    f_test = zeros(nx, ny) - 1
    for i = 1:min(nx, N)
        f_test[i, rand(1:ny)] = 1 
    end
    return f_test
end;

function computeTransformGivenCorrespondences(scenePoints::Array{Float64}, points, faces,
    f_completed::Array{Float64}, f_outlier_completed::Array{Float64}, R_init::Array{Float64}, T_init::Array{Float64}, C_init::Array{Float64})
    
    function projectRotMat(R::Array{Float64})
        return RotMatrix(Quat(R))
    end
    
    modelVerts = Array{Float64}(3, size(points, 1))
    for i=1:size(points, 1)
        for k=1:3
            modelVerts[k, i] = points[i][k]
        end
    end
    # Build vertex-membership matrix F
    # where F[i, j] == 1 --> 
    #         vertex j is a member of face i
    F = Array{Float64}(size(faces, 1), size(points, 1))
    F .= 0.0
    for i = 1:size(faces, 1)
        for j = faces[i]
            F[i, j] = 1
        end
    end
    
    function computeObjective(args)
        R = reshape(args[1:9], 3, 3)
        T = args[10:12]
        C = reshape(args[13:end], size(scenePoints, 2), size(points, 1))
        total_err = 0.
        for i = 1:size(scenePoints, 2)
            if f_outlier_completed[i] == 0
                total_err += norm(R * scenePoints[:, i] + T - modelVerts * C[i, :], 1)
            end
        end
        return total_err / size(scenePoints, 2)
    end
    
    #=
    m = Model()
    @variable(m, -1. <= R[i=1:3, j=1:3] <= 1., start = R_init[i, j])
    @variable(m, T[i=1:3], start = T_init[i])
    @variable(m, 0. <= C[i=1:size(scenePoints, 2), j=1:size(points, 1)] <= 1., start = C_init[i, j])
    @variable(m, 0. <= obj_helper[1:size(scenePoints, 2)])
    
    for i = 1:size(scenePoints, 2)
        if f_outlier_completed[i] == 0
            @constraint(m, obj_helper[i] == norm(R * scenePoints[:, i] + T - modelVerts * C[i, :]))
            for k = 1:size(faces, 1)
                if f_completed[i, k] == 0
                    @constraint(m, C[i, ])
                    for ind in faces[k]
                        @constraint(m, C[i, ind] == 1.)
                    end
                end
            end
        else
            @constraint(m, obj_helper[i] == 0)
            @constraint(m, C[i, :] == 0)
        end 
    end
    @objective(m, Min, sum( [obj_helper] ))
    =#
    
    R = R_init
    T = T_init
    C = C_init
    args_concat = vcat(reshape(R, 9, 1), T, reshape(C, size(C, 1)*size(C, 2), 1))
    cfg = ForwardDiff.GradientConfig(args_concat)
    
    # Momentum for gradient descent
    velocity = args_concat * 0.0
    err = 0
    C_temp = 0
    for k = 1:100
        err = computeObjective(args_concat) 
        derr = ForwardDiff.gradient(computeObjective, args_concat, cfg)
        #println(k, ": ", err)
        
        grad_component = derr .* derr
        # Compute update
        #println(grad_component)
        delta = velocity - (1./abs(grad_component+1.)) .* derr * 0.05
        args_concat += delta

        # Update velocity with momentum amount
        velocity = delta*0.9
        
        # Reproject R to be a rotation matrix
        r_temp = reshape(args_concat[1:9], 3, 3)
        args_concat[1:9] = reshape(projectRotMat(r_temp), 9, 1)
        # Reproject C to only contain the faces we're allowed to use
        C_temp = reshape(args_concat[13:end], size(C, 1), size(C, 2))
        C_mask = C_temp * 0.
        for i in 1:size(C, 1)
            if f_outlier_completed[i] == 1
                C_mask[i, :] = 0
                break
            else
                for j in 1:size(C, 2)
                    for k in faces[findfirst(f_completed[i, :])]
                        C_mask[i, k] = 1.
                    end
                end
            end
        end
        C_temp = C_temp .* C_mask
        args_concat[13:end] = reshape(C_temp, size(C, 1)*size(C, 2), 1)
    end
    
    R_proj = projectRotMat(R_init)
    
   # println("Final error: ", err)
    
    return (R_proj, T_init)
end

f_test = scenePointsFacesGT
f_outlier_test = outliersGTAssignment
R_test, T_test = computeTransformGivenCorrespondences(scenePoints, points, faces, f_test, f_outlier_test, rand(3, 3), rand(3, 1), rand(size(scenePoints, 2), size(points, 1)));
println(R_test, ", ", T_test)
println(R0, ", ", T0)
# Out:
# [0.361169 -0.159158 0.918818; -0.687168 0.620647 0.377621; -0.630363 -0.767767 0.11479], [0.917409; 0.925262; 0.535491]
# [0.860089 0.174349 -0.479426; 0.244566 0.683829 0.687434; 0.447698 -0.708506 0.545514], [0.1,0.0,0.5]
# WARNING: Method definition buildRandomPartialFaceAssignment(Any, Any, Any, Any) in module Main at In[205]:2 overwritten at In[209]:2.
# WARNING: Method definition computeTransformGivenCorrespondences(Array{Float64, N<:Any}, Any, Any, Array{Float64, N<:Any}, Array{Float64, N<:Any}, Array{Float64, N<:Any}, Array{Float64, N<:Any}, Array{Float64, N<:Any}) in module Main at In[205]:14 overwritten at In[209]:14.

# %% [markdown]
# We're going to tackle this by performing branch and bound over the correspondences $f$, where $f[i, k] \implies \text{$s_i$ is on face $k$}$. (You'll have to inspect the detailed problem formulation to find $f$, sorry!)
#
# Given a *partial assignment* of $f$, we can build an LP $LP_{relax}$ by relaxing the unassigned members of $f$ to be continuous. Given its corresponding relaxed solution, including the pseudo-rotation $\hat{R}$, we can:
# - *Branch*: Pick a free member of $f$ (i.e. one that is not assigned to 0 or 1 already) and create two new partial assignments, where that assignment is 0, and where that assignment is 1.
# - *Provide a lower bound*: The optimal value of the relaxed solution already provides a lower bound. By looking at $R$, $\hat{R}$, and the cost vector of $LP_{relax}$, I suspect we can improve the lower bound by moving backwards (i.e. upwards in cost) along the cost vector until some part of $SO(3)$ is in the null space of the cost vector.
# - *Provide an upper bound*: "Complete" the relaxed solution by rounding the correspondences to make all binary assignments truly binary. Solve that to get an intermediate rotation $\hat{R}$. Project $\hat{R}$ into $SO(3)$ to yield $\bar{R}$, and solve $LP_{relax}$ one more time with $R == \bar{R}$ and the correspondences still rounded. (Alternative, maybe more efficient: then account for $R \notin SO(3)$ by projecting $\hat{R} - \bar{R}$ onto the cost vector, where $\bar{R}$ is a valid rotation (chosen by projecting $\hat{R}$ onto $SO(3)$), and adding that to the "completed" solution's cost.)

# %%
# Datastructure for the search tree
module CorrespondenceBnB
type PartialAssignmentNode
    # A partial-assignment of f has entries [-1, 0, and 1], 
    # where [0 and 1] are valid assignments, and [-1] is 
    # no-assignment.
    f_assign::Array{Float64} # A partial assignment of f
    f_outlier_assign::Array{Float64} # A partial assignment of f
    
    lower_bound::Float64
    upper_bound::Float64
    
    # List of children nodes (possible empty)
    children::Array{PartialAssignmentNode}
    
    # Parent (or nothing)
    parent::Nullable{PartialAssignmentNode}
    
    # Is this node known to be fathomed?
    is_fathomed::Bool
end
type NodeHistory
    node_hash_table::Array{Array{PartialAssignmentNode}}
end
end

using CorrespondenceBnB

function spawnChildNode(node::CorrespondenceBnB.PartialAssignmentNode)
    return CorrespondenceBnB.PartialAssignmentNode(
    copy(node.f_assign),
    copy(node.f_outlier_assign),
    node.lower_bound,
    node.upper_bound,
    [],
    node,
    false
    )
end
    
    
function printNodeSummary(node::CorrespondenceBnB.PartialAssignmentNode)
    num_pos_assignments = sum( node.f_assign .== 1.0 )
    num_neg_assignments = sum( node.f_assign .== 0.0 )
    num_pos_outlier_assignments = sum( node.f_outlier_assign .== 1.0)
    num_neg_outlier_assignments = sum( node.f_outlier_assign .== 0.0)
    @printf("Node (+%d/-%d | +%d/-%d outlier) [%f <= opt <= %f] ", num_pos_assignments,
    num_neg_assignments, num_pos_outlier_assignments, num_neg_outlier_assignments,
    node.lower_bound, node.upper_bound)
    if (node.is_fathomed)
        print("is fathomed\n")
    else
        print("is not fathomed\n")
    end
end

function processNode(fullyRelaxedModel::PoseEstimationSolveData, node::CorrespondenceBnB.PartialAssignmentNode, best_known_upper_bound::Float64)
    """
    Takes the base model for this search, and a
    node that has been populated with a partial
    assignment and an optional parent.
    
    Computes a lower and upper bound from the partial
    assignment, and generates a list of child nodes
    from all assignments of an unassigned 
    scene point, OR declares this node fathomed.
    """
    
    # Apply the partial assignments
    partiallyAssignedModel = buildModelHelper()
    for (i, val) = enumerate(node.f_assign)
        if (val == 0.0 || val == 1.0)
            @constraint(partiallyAssignedModel.m, partiallyAssignedModel.f[i] == val)
            #println("Assigned ", ind2sub(node.f_assign, i), " to ", val)
        end
    end
    for (i, val) = enumerate(node.f_outlier_assign)
        if (val == 0.0 || val == 1.0)
            @constraint(partiallyAssignedModel.m, partiallyAssignedModel.f_outlier[i] == val)
            #println("Assigned outlier ", ind2sub(node.f_outlier_assign, i), " to ", val)
        end
    end
    status = solve(partiallyAssignedModel.m)
    
    # Lower bound from the relaxation
    node.lower_bound = getobjectivevalue(partiallyAssignedModel.m)
    
    # Check if we're obviated by some other known bound:
    if (best_known_upper_bound != nothing 
        && node.lower_bound >= best_known_upper_bound)
        node.is_fathomed = true
        node.upper_bound = Inf
        node.children = []
        return node
    end
    
    # Upper bound:
    # First, complete the solution to make f binary
    f_completed::Array{Float64} = Array{Float64}(getvalue(partiallyAssignedModel.f))
    f_outlier_completed::Array{Float64} = Array{Float64}(getvalue(partiallyAssignedModel.f_outlier))
    (maxval, index) = findmax(f_completed, 2)
    for (i, k) = enumerate(index)
        if maxval[i] < f_outlier_completed[i]
            f_completed[i, :] = 0.
            f_outlier_completed[i] = 1.
        else
            f_completed[i, :] = 0.
            f_completed[k] = 1.
            f_outlier_completed[i] = 0.
        end
    end
    
    #  Given that completed solution, generate the optimal
    #  transform for each rigid body
    (Rbar, Tbar) = computeTransformGivenCorrespondences(scenePoints, points, faces, f_completed, f_outlier_completed,
    getvalue(partiallyAssignedModel.R), getvalue(partiallyAssignedModel.T), getvalue(partiallyAssignedModel.C))
    
    
    # Build a new model with f forced to take these values
    fCompletedModel = partiallyAssignedModel #buildModelHelper()
    @constraint(fCompletedModel.m, fCompletedModel.f .== f_completed)
    @constraint(fCompletedModel.m, fCompletedModel.f_outlier .== f_outlier_completed)
    @constraint(fCompletedModel.m, fCompletedModel.R .== Rbar)
    status = solve(fCompletedModel.m)
    node.upper_bound = getobjectivevalue(fCompletedModel.m)
    
    # Check if we're fathomed by feasibility by checking bounds
    if (node.upper_bound < node.lower_bound)
        println("Serious problem: upper bound lower than upper bound!")
        node.lower_bound = 0.
        node.upper_bound = 0.
    end
    if (node.upper_bound - node.lower_bound < 0.0001)
        node.is_fathomed = true
        node.children = []
        return node
    end
    
    index_to_assign = 1
    while index_to_assign <= size(node.f_assign, 1)
        if min(node.f_outlier_assign[index_to_assign],
           minimum(node.f_assign[index_to_assign, :], 1)[1]) < 0
            # Not assigned yet!
            break
        else
            index_to_assign += 1
        end
    end
    
    if (index_to_assign > size(node.f_assign, 1))
        # We're fully specified -- this is another way to be fathomed
        node.children = []
        node.is_fathomed = true
        return node
    end
    
    # Finally, populate all children
    
    node.children = []    
    for correspondence_to_assign in 0:size(node.f_assign, 2)
        push!(node.children, spawnChildNode(node))
        if (correspondence_to_assign == 0)
            node.children[correspondence_to_assign+1].f_assign[index_to_assign, :] = 0.
            node.children[correspondence_to_assign+1].f_outlier_assign[index_to_assign] = 1.
        elseif (correspondence_to_assign > 0)
            node.children[correspondence_to_assign+1].f_outlier_assign[index_to_assign] = 0.
            node.children[correspondence_to_assign+1].f_assign[index_to_assign, :] = 0.
            node.children[correspondence_to_assign+1].f_assign[index_to_assign, correspondence_to_assign] = 1.
        end
    end
    
    return node
end

f_test = buildRandomPartialFaceAssignment(scenePoints, faces, points, 0)
f_outlier_test = zeros(size(scenePointsFacesGT, 1), 1)-1
f_test = scenePointsFacesGT
f_outlier_test = outliersGTAssignment
test_node = CorrespondenceBnB.PartialAssignmentNode(f_test, f_outlier_test, 0.0, Inf, [], nothing, false)
printNodeSummary(test_node)
test_node = processNode(fullyRelaxedModel, test_node, 100.);
printNodeSummary(test_node)
println("Children:")
for child in test_node.children
    printNodeSummary(processNode(fullyRelaxedModel, child, 100.))
end
# Out:
# Node (+8/-112 | +2/-8 outlier) [0.000000 <= opt <= Inf] is not fathomed
# Final error:
# WARNING: replacing module CorrespondenceBnB
# 0.07686860705245555
# Node (+8/-112 | +2/-8 outlier) [0.020000 <= opt <= 0.099893] is fathomed
# Children:

# %%
function compareNodes(a::CorrespondenceBnB.PartialAssignmentNode, b::CorrespondenceBnB.PartialAssignmentNode)
    if a == b
        return true
    end
    
    for i = 1 : size(a.f_assign, 1)
        if a.f_outlier_assign[i] != b.f_outlier_assign
            return false
        end
        
        for j = 1 : size(a.f_assign, 2)
            if a.f_assign[i, j] != b.f_assign[i, j]
                return false
            end
        end
    end
    
    return true
end

# If the given node is in the nodeHistory already, returns false.
# Otherwise, adds it to the node history and returns true.
function tryInsertNodeInTable(nodeHistory::CorrespondenceBnB.NodeHistory, node::CorrespondenceBnB.PartialAssignmentNode)
    # "Hash" by summing the index of the correspondences
    ind = 0
    for i = 1 : size(node.f_assign, 1)
        if node.f_outlier_assign[i] == 1
            continue
        else
            ind += findfirst(node.f_assign[i, :])
        end
    end
    ind = (ind % size(nodeHistory.node_hash_table, 1)) + 1
    
    alreadyInHistory = false
    for oldNode in nodeHistory.node_hash_table[ind]
        if compareNodes(node, oldNode)
            alreadyInHistory = true
            break
        end
    end
    
    if alreadyInHistory
        return false
    else
        push!(nodeHistory.node_hash_table[ind], node)
        return true
    end
end;
# Out:
# WARNING: Method definition compareNodes(CorrespondenceBnB.PartialAssignmentNode, CorrespondenceBnB.PartialAssignmentNode) in module Main at In[207]:2 overwritten at In[210]:2.
# WARNING: Method definition tryInsertNodeInTable(CorrespondenceBnB.NodeHistory, CorrespondenceBnB.PartialAssignmentNode) in module Main at In[207]:25 overwritten at In[210]:25.

# %%
module CorrespondenceBnBHistory
type SolveHistory
    elapsed::Array{Float64}
    best_ub::Array{Float64}
    best_lb::Array{Float64}
    searched::Array{Int}
    queued::Array{Int}
    done::Array{Int}
end
end

function updateTree(node::CorrespondenceBnB.PartialAssignmentNode)
    # Updates this node by checking the children's
    # lb and ub, and then recursively calls this on 
    # the parent
    if size(node.children, 1) != 0
        old_lb = node.lower_bound
        node.lower_bound = min(minimum([child.lower_bound for child in node.children]))
        node.upper_bound = max(maximum([child.upper_bound for child in node.children]))
    end
        
    if !isnull(node.parent)
        updateTree(get(node.parent))
    end
end

function runCorrespondenceBranchAndBound(scenePoints, faces, points, f_start, f_outlier_start)
    # Set up root node for our search
    fullyRelaxedModel = buildModelHelper()
    
    # Set up node history
    nodeHistory = CorrespondenceBnB.NodeHistory(repeat([[]], outer=100))
    
    root_node = CorrespondenceBnB.PartialAssignmentNode(f_start, f_outlier_start, 0.0, Inf, [], nothing, false)
    best_known_upper_bound = root_node.upper_bound
    # Remember that Julia's priority queue returns LOWEST priority items first.
    leaf_queue = PriorityQueue(CorrespondenceBnB.PartialAssignmentNode, Float64)
    enqueue!(leaf_queue, root_node, root_node.lower_bound)
    
    # And solve history
    solveHistory = CorrespondenceBnBHistory.SolveHistory([0.0], [root_node.upper_bound], [root_node.lower_bound], [0], [1], [0])
    
    if !tryInsertNodeInTable(nodeHistory, root_node)
        println("Couldn't insert root node in nodeHistory. Bug!")
        return false
    end
    
    incumbent_sol = root_node
    num_fathomed = 0
    for k in 1:10000
        if length(leaf_queue) == 0
            println("Queue empty!")
            @printf("Searched %d, queue %d, fathomed %d, best bounds %f <= x <= %f\n", k, length(leaf_queue), num_fathomed, root_node.lower_bound, best_known_upper_bound)
            print("Incumbent: "); printNodeSummary(incumbent_sol)
            break
        end
        next_node = dequeue!(leaf_queue)
        
        # Process this node to generate its bounds and detect if it's fathomed
        next_node = processNode(fullyRelaxedModel, next_node, best_known_upper_bound)
        
        if (k % 50 == 0)
            print("*******\nLast node : ")
            printNodeSummary(next_node)
            print("Incumbent : ")
            printNodeSummary(incumbent_sol)
            @printf("Searched %d, queue %d, fathomed %d, best bounds %f <= x <= %f\n", k, length(leaf_queue), num_fathomed, root_node.lower_bound, best_known_upper_bound)
        end
        # Did we improve our upper bound estimate?
        best_known_upper_bound = min(next_node.upper_bound, best_known_upper_bound)
        
        updateTree(next_node)
        
        if next_node.is_fathomed
            num_fathomed += 1
            # It may have been fathomed by having a bad lower bound;
            # if it wasn't (it was feasible!), then lb == ub and
            # we should take it as incumbent if it's a better sol.
            # (If lb > best_known_upper_bound, this check will fail, so 
            # we don't need to explicitely handle the first case)
            if next_node.upper_bound <= best_known_upper_bound
                incumbent_sol = next_node
            end
        else
            for child in next_node.children
                if tryInsertNodeInTable(nodeHistory, child)
                    enqueue!(leaf_queue, child, next_node.lower_bound)
                end
            end
        end
    end
end;

f_test = buildRandomPartialFaceAssignment(scenePoints, faces, points, 0)
f_outlier_test = zeros(Float64, size(scenePointsFacesGT, 1), 1) - 1
runCorrespondenceBranchAndBound(scenePoints, faces, points, f_test, f_outlier_test);
# Out:
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.318692] is fathomed
# Incumbent : Node (+0/-0 | +0/-0 outlier) [0.000000 <= opt <= 2.609267] is not fathomed
# Searched 50, queue 419, fathomed 13, best bounds 0.000000 <= x <= 1.834595
# WARNING: replacing module CorrespondenceBnBHistory
# WARNING: Method definition updateTree(CorrespondenceBnB.PartialAssignmentNode) in module Main at In[208]:16 overwritten at In[211]:16.
# WARNING: Method definition runCorrespondenceBranchAndBound(Any, Any, Any, Any, Any) in module Main at In[208]:29 overwritten at In[211]:29.
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.299246] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 100, queue 525, fathomed 51, best bounds 0.000000 <= x <= 1.106140
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.011471 <= opt <= 2.111371] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 150, queue 618, fathomed 90, best bounds 0.000000 <= x <= 1.106140
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.077274 <= opt <= 0.340749] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 200, queue 1023, fathomed 105, best bounds 0.000000 <= x <= 1.065934
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.001579 <= opt <= 2.081988] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 250, queue 1194, fathomed 138, best bounds 0.000000 <= x <= 0.340749
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.003773 <= opt <= 2.033218] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 300, queue 1183, fathomed 185, best bounds 0.000000 <= x <= 0.340749
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.003773 <= opt <= 2.040654] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 350, queue 1289, fathomed 223, best bounds 0.000000 <= x <= 0.340749
# *******
# Last node : Node (+3/-33 | +0/-3 outlier) [0.003689 <= opt <= 1.930381] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 400, queue 1733, fathomed 235, best bounds 0.000000 <= x <= 0.340749
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.033715 <= opt <= 2.055556] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 450, queue 1982, fathomed 262, best bounds 0.000000 <= x <= 0.340749
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.284629] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 500, queue 1932, fathomed 312, best bounds 0.000000 <= x <= 0.340749
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.046627] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 550, queue 1934, fathomed 358, best bounds 0.000000 <= x <= 0.340749
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.068622 <= opt <= 0.171382] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 600, queue 2209, fathomed 383, best bounds 0.000000 <= x <= 0.340749
# *******
# Last node : Node (+5/-55 | +0/-5 outlier) [0.000000 <= opt <= 2.440933] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 650, queue 2809, fathomed 383, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+6/-66 | +0/-6 outlier) [0.000000 <= opt <= 2.527556] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 700, queue 3409, fathomed 383, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.005311 <= opt <= 2.148042] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 750, queue 3658, fathomed 410, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.033715 <= opt <= 2.092533] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 800, queue 3842, fathomed 442, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.165452] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 850, queue 3844, fathomed 488, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.171292] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 900, queue 3846, fathomed 534, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.169425] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 950, queue 3887, fathomed 577, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.158321] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 1000, queue 3889, fathomed 623, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.033715 <= opt <= 2.083440] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 1050, queue 3865, fathomed 671, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.384629] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 1100, queue 3815, fathomed 721, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.195712] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 1150, queue 4272, fathomed 732, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.000000 <= opt <= 2.143631] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 1200, queue 4560, fathomed 756, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.000000 <= opt <= 2.224433] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 1250, queue 4965, fathomed 771, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.068926 <= opt <= 0.457185] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 1300, queue 5526, fathomed 774, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+6/-66 | +0/-6 outlier) [0.000000 <= opt <= 2.364691] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 1350, queue 6061, fathomed 779, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+8/-88 | +0/-8 outlier) [0.000000 <= opt <= 2.127007] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 1400, queue 6310, fathomed 806, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+5/-55 | +0/-5 outlier) [0.000315 <= opt <= 2.045429] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 1450, queue 6858, fathomed 810, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+4/-44 | +0/-4 outlier) [0.074153 <= opt <= 2.005706] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 1500, queue 7406, fathomed 814, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.068926 <= opt <= 1.338825] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 1550, queue 7993, fathomed 815, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.014597 <= opt <= 1.969195] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 1600, queue 8333, fathomed 835, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+8/-88 | +0/-8 outlier) [0.098114 <= opt <= 1.498644] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 1650, queue 8569, fathomed 863, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.033713 <= opt <= 2.322566] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 1700, queue 8961, fathomed 879, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+8/-88 | +0/-8 outlier) [0.066837 <= opt <= 1.536144] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 1750, queue 9184, fathomed 908, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+6/-78 | +1/-6 outlier) [0.010000 <= opt <= 2.353298] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 1800, queue 9771, fathomed 909, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+6/-66 | +0/-6 outlier) [0.000000 <= opt <= 2.416526] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 1850, queue 10371, fathomed 909, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+5/-55 | +0/-5 outlier) [0.003039 <= opt <= 2.320396] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 1900, queue 10971, fathomed 909, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+6/-66 | +0/-6 outlier) [0.098838 <= opt <= 2.361548] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 1950, queue 11519, fathomed 913, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.000000 <= opt <= 2.338897] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 2000, queue 11911, fathomed 929, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.369431] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 2050, queue 12056, fathomed 964, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+6/-66 | +0/-6 outlier) [0.050155 <= opt <= 2.076253] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 2100, queue 12279, fathomed 993, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.000000 <= opt <= 2.405712] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 2150, queue 12879, fathomed 993, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.276971] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 2200, queue 13128, fathomed 1020, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.004700 <= opt <= 1.944819] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 2250, queue 13130, fathomed 1066, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.276971] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 2300, queue 13548, fathomed 1080, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.003191 <= opt <= 2.274030] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 2350, queue 13667, fathomed 1117, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.000000 <= opt <= 2.157575] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 2400, queue 14033, fathomed 1135, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.169497] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 2450, queue 14373, fathomed 1155, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.000000 <= opt <= 2.238126] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 2500, queue 14882, fathomed 1162, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.027955 <= opt <= 1.960203] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 2550, queue 15118, fathomed 1190, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.006630 <= opt <= 2.097019] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 2600, queue 15185, fathomed 1231, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.027955 <= opt <= 1.990313] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 2650, queue 15369, fathomed 1263, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.031141] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 2700, queue 15332, fathomed 1312, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.016484 <= opt <= 2.289871] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 2750, queue 15490, fathomed 1346, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.394853] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 2800, queue 15492, fathomed 1392, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.016484 <= opt <= 2.279984] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 2850, queue 15819, fathomed 1413, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.008357 <= opt <= 2.188444] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 2900, queue 15886, fathomed 1454, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.351794] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 2950, queue 15979, fathomed 1493, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.016484 <= opt <= 2.329521] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 3000, queue 15994, fathomed 1538, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.011471 <= opt <= 2.165133] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 3050, queue 16113, fathomed 1575, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.012114 <= opt <= 2.271493] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 3100, queue 16167, fathomed 1617, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.016484 <= opt <= 2.256460] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 3150, queue 16221, fathomed 1659, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.019200 <= opt <= 1.949012] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 3200, queue 16327, fathomed 1697, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.017044 <= opt <= 1.141964] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 3250, queue 16667, fathomed 1717, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.000000 <= opt <= 2.318318] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 3300, queue 17020, fathomed 1736, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.134557] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 3350, queue 17568, fathomed 1740, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.320394] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 3400, queue 17895, fathomed 1761, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.000000 <= opt <= 2.306563] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 3450, queue 18157, fathomed 1787, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.023064 <= opt <= 1.329820] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 3500, queue 18575, fathomed 1801, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.010846 <= opt <= 1.180331] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 3550, queue 19071, fathomed 1809, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.225882] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 3600, queue 19632, fathomed 1812, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.000000 <= opt <= 2.529876] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 3650, queue 20180, fathomed 1816, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.386383] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 3700, queue 20585, fathomed 1831, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.404435] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 3750, queue 20756, fathomed 1864, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+5/-55 | +0/-5 outlier) [0.001674 <= opt <= 1.979076] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 3800, queue 21239, fathomed 1873, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.000000 <= opt <= 2.520252] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 3850, queue 21462, fathomed 1902, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+8/-88 | +0/-8 outlier) [0.000000 <= opt <= 2.351422] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 3900, queue 22010, fathomed 1906, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+6/-66 | +0/-6 outlier) [0.032775 <= opt <= 2.097768] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 3950, queue 22259, fathomed 1933, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.000000 <= opt <= 2.186383] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 4000, queue 22820, fathomed 1936, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+4/-44 | +0/-4 outlier) [0.000000 <= opt <= 1.997940] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 4050, queue 23381, fathomed 1939, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.286383] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 4100, queue 23721, fathomed 1959, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.245295] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 4150, queue 23996, fathomed 1984, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.000000 <= opt <= 2.574651] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 4200, queue 24401, fathomed 1999, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+6/-66 | +0/-6 outlier) [0.000000 <= opt <= 2.366987] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 4250, queue 24975, fathomed 2001, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.021384 <= opt <= 1.358682] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 4300, queue 25497, fathomed 2007, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+6/-66 | +0/-6 outlier) [0.099967 <= opt <= 1.423218] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 4350, queue 25993, fathomed 2015, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+5/-55 | +0/-5 outlier) [0.000000 <= opt <= 2.128610] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 4400, queue 26437, fathomed 2027, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+6/-66 | +0/-6 outlier) [0.100000 <= opt <= 2.391073] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 4450, queue 26972, fathomed 2032, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.005545 <= opt <= 2.119404] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 4500, queue 27169, fathomed 2063, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+8/-88 | +0/-8 outlier) [0.007005 <= opt <= 1.355852] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 4550, queue 27587, fathomed 2077, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.176971] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 4600, queue 27901, fathomed 2099, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.288028] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 4650, queue 28163, fathomed 2125, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.357575] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 4700, queue 28113, fathomed 2175, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.168179] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 4750, queue 28583, fathomed 2185, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.268632] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 4800, queue 28533, fathomed 2235, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.268179] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 4850, queue 28613, fathomed 2275, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.024665 <= opt <= 2.203043] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 4900, queue 28732, fathomed 2312, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.017841 <= opt <= 2.079449] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 4950, queue 28760, fathomed 2356, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.413113] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 5000, queue 28931, fathomed 2389, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.024810 <= opt <= 2.361406] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 5050, queue 29011, fathomed 2429, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.017841 <= opt <= 2.133608] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 5100, queue 29156, fathomed 2464, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.008189 <= opt <= 2.104223] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 5150, queue 29197, fathomed 2507, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+8/-88 | +0/-8 outlier) [0.000000 <= opt <= 2.250903] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 5200, queue 29303, fathomed 2545, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.018754 <= opt <= 2.069926] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 5250, queue 29435, fathomed 2581, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.017841 <= opt <= 2.225049] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 5300, queue 29632, fathomed 2612, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.389502] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 5350, queue 29712, fathomed 2652, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.018754 <= opt <= 2.129637] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 5400, queue 29714, fathomed 2698, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.231363] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 5450, queue 29872, fathomed 2732, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.168632] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 5500, queue 29952, fathomed 2772, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+8/-88 | +0/-8 outlier) [0.081655 <= opt <= 1.145203] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 5550, queue 30123, fathomed 2805, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.033715 <= opt <= 2.107613] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 5600, queue 30320, fathomed 2836, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.018754 <= opt <= 2.011866] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 5650, queue 30452, fathomed 2872, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.304259] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 5700, queue 30493, fathomed 2915, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.017841 <= opt <= 2.163242] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 5750, queue 30599, fathomed 2953, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.018754 <= opt <= 2.100547] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 5800, queue 30601, fathomed 2999, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.033715 <= opt <= 2.233590] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 5850, queue 30850, fathomed 3026, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+8/-100 | +1/-8 outlier) [0.010000 <= opt <= 1.288965] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 5900, queue 30852, fathomed 3072, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.018754 <= opt <= 2.067830] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 5950, queue 30945, fathomed 3111, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.037520 <= opt <= 1.945541] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 6000, queue 31077, fathomed 3147, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.017841 <= opt <= 2.122422] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 6050, queue 31274, fathomed 3178, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+8/-88 | +0/-8 outlier) [0.104293 <= opt <= 2.197544] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 6100, queue 31315, fathomed 3221, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.008189 <= opt <= 1.835578] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 6150, queue 31577, fathomed 3247, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.022624 <= opt <= 2.153020] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 6200, queue 31709, fathomed 3283, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.235450] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 6250, queue 31750, fathomed 3326, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.020762 <= opt <= 2.069002] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 6300, queue 31817, fathomed 3367, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.027516 <= opt <= 2.130263] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 6350, queue 31832, fathomed 3412, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.027516 <= opt <= 2.179591] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 6400, queue 31938, fathomed 3450, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.008189 <= opt <= 2.013420] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 6450, queue 32135, fathomed 3481, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.308190] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 6500, queue 32176, fathomed 3524, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.020762 <= opt <= 2.203655] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 6550, queue 32269, fathomed 3563, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.017841 <= opt <= 2.086926] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 6600, queue 32466, fathomed 3594, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.013479 <= opt <= 2.171496] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 6650, queue 32507, fathomed 3637, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.000000 <= opt <= 2.292788] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 6700, queue 32925, fathomed 3651, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.357575] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 6750, queue 33382, fathomed 3662, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.000000 <= opt <= 2.569431] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 6800, queue 33618, fathomed 3690, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.588028] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 6850, queue 34036, fathomed 3704, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+8/-88 | +0/-8 outlier) [0.000000 <= opt <= 2.310185] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 6900, queue 34389, fathomed 3723, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+6/-66 | +0/-6 outlier) [0.000000 <= opt <= 2.388028] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 6950, queue 34989, fathomed 3723, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+4/-44 | +0/-4 outlier) [0.001722 <= opt <= 2.277249] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 7000, queue 35186, fathomed 3754, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+8/-88 | +0/-8 outlier) [0.000000 <= opt <= 2.206485] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 7050, queue 35773, fathomed 3755, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.004351 <= opt <= 2.113886] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 7100, queue 36113, fathomed 3775, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+6/-66 | +0/-6 outlier) [0.033230 <= opt <= 2.047686] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 7150, queue 36336, fathomed 3804, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+5/-55 | +0/-5 outlier) [0.002632 <= opt <= 2.257234] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 7200, queue 36871, fathomed 3809, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+6/-66 | +0/-6 outlier) [0.000000 <= opt <= 2.167737] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 7250, queue 37471, fathomed 3809, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.179000] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 7300, queue 38019, fathomed 3813, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.000000 <= opt <= 2.275273] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 7350, queue 38437, fathomed 3827, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+8/-88 | +0/-8 outlier) [0.000000 <= opt <= 1.963474] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 7400, queue 38816, fathomed 3844, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+5/-55 | +0/-5 outlier) [0.000000 <= opt <= 2.272880] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 7450, queue 39013, fathomed 3875, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.000000 <= opt <= 2.172977] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 7500, queue 39587, fathomed 3877, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+6/-66 | +0/-6 outlier) [0.000000 <= opt <= 2.149081] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 7550, queue 39836, fathomed 3904, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.089816] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 7600, queue 40215, fathomed 3921, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+6/-66 | +0/-6 outlier) [0.000000 <= opt <= 2.173952] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 7650, queue 40581, fathomed 3939, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+5/-55 | +0/-5 outlier) [0.000000 <= opt <= 2.148993] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 7700, queue 41038, fathomed 3950, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+5/-55 | +0/-5 outlier) [0.000000 <= opt <= 2.275431] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 7750, queue 41417, fathomed 3967, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.016177 <= opt <= 2.149521] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 7800, queue 41835, fathomed 3981, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+8/-88 | +0/-8 outlier) [0.000000 <= opt <= 2.500601] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 7850, queue 42123, fathomed 4005, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.047263 <= opt <= 2.102534] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 7900, queue 42476, fathomed 4024, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.233327] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 7950, queue 42595, fathomed 4061, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.016177 <= opt <= 2.251304] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 8000, queue 42857, fathomed 4087, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+3/-33 | +0/-3 outlier) [0.000000 <= opt <= 2.127479] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 8050, queue 43041, fathomed 4119, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.094345] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 8100, queue 43303, fathomed 4145, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.047263 <= opt <= 2.069507] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 8150, queue 43409, fathomed 4183, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.011864 <= opt <= 2.040769] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 8200, queue 43593, fathomed 4215, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+6/-66 | +0/-6 outlier) [0.000000 <= opt <= 2.415482] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 8250, queue 44102, fathomed 4222, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.000000 <= opt <= 2.406341] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 8300, queue 44260, fathomed 4256, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+8/-88 | +0/-8 outlier) [0.000000 <= opt <= 2.177836] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 8350, queue 44691, fathomed 4269, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+6/-66 | +0/-6 outlier) [0.000000 <= opt <= 2.389654] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 8400, queue 45161, fathomed 4279, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.047263 <= opt <= 2.080106] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 8450, queue 45527, fathomed 4297, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.000000 <= opt <= 2.233087] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 8500, queue 45763, fathomed 4325, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.283878] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 8550, queue 46337, fathomed 4327, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000743 <= opt <= 2.257074] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 8600, queue 46313, fathomed 4375, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.002802 <= opt <= 2.015599] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 8650, queue 46315, fathomed 4421, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.036013 <= opt <= 1.101805] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 8700, queue 46421, fathomed 4459, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+8/-88 | +0/-8 outlier) [0.000000 <= opt <= 2.199818] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 8750, queue 46800, fathomed 4476, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.000000 <= opt <= 2.395463] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 8800, queue 47309, fathomed 4483, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.000000 <= opt <= 2.179648] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 8850, queue 47870, fathomed 4486, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.045087 <= opt <= 2.346488] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 8900, queue 48210, fathomed 4506, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+5/-55 | +0/-5 outlier) [0.000000 <= opt <= 1.962487] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 8950, queue 48654, fathomed 4518, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.006225 <= opt <= 1.239184] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 9000, queue 49059, fathomed 4533, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+5/-67 | +1/-5 outlier) [0.010000 <= opt <= 2.126330] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 9050, queue 49399, fathomed 4553, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.000000 <= opt <= 2.176971] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 9100, queue 49739, fathomed 4573, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.280642] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 9150, queue 50066, fathomed 4594, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.174258] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 9200, queue 50302, fathomed 4622, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.000000 <= opt <= 2.190672] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 9250, queue 50460, fathomed 4656, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+6/-66 | +0/-6 outlier) [0.000000 <= opt <= 2.101905] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 9300, queue 50722, fathomed 4682, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.000000 <= opt <= 2.354460] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 9350, queue 50919, fathomed 4713, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.047263 <= opt <= 2.130417] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 9400, queue 51051, fathomed 4749, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+8/-88 | +0/-8 outlier) [0.100000 <= opt <= 2.285458] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 9450, queue 51287, fathomed 4777, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.284629] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 9500, queue 51458, fathomed 4810, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.010069 <= opt <= 2.145679] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 9550, queue 51863, fathomed 4825, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.000000 <= opt <= 2.401769] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 9600, queue 52112, fathomed 4852, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+9/-99 | +0/-9 outlier) [0.000000 <= opt <= 2.168069] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 9650, queue 52361, fathomed 4879, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+7/-77 | +0/-7 outlier) [0.000000 <= opt <= 2.247815] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 9700, queue 52818, fathomed 4890, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.353581] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 9750, queue 53262, fathomed 4902, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+4/-44 | +0/-4 outlier) [0.000000 <= opt <= 2.244025] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 9800, queue 53667, fathomed 4917, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+8/-88 | +0/-8 outlier) [0.030894 <= opt <= 2.092841] is not fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 9850, queue 54267, fathomed 4917, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.284254] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 9900, queue 54490, fathomed 4946, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.000000 <= opt <= 2.304777] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 9950, queue 54440, fathomed 4996, best bounds 0.000000 <= x <= 0.171382
# *******
# Last node : Node (+10/-110 | +0/-10 outlier) [0.021172 <= opt <= 2.241147] is fathomed
# Incumbent : Node (+9/-111 | +1/-9 outlier) [0.010000 <= opt <= 1.106140] is fathomed
# Searched 10000, queue 54520, fathomed 5036, best bounds 0.000000 <= x <= 0.171382

# %%
using ProfileView
Profile.clear()  # in case we have any previous profiling data
@profile runCorrespondenceBranchAndBound(scenePoints, faces, points, f_test, f_outlier_test);

# %%
ProfileView.view()
